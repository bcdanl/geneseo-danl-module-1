# %% [raw]
# ---
# title: Take-home Exam
# date: 2024-03-19
# execute:
#   echo: true
#   eval: false
#   warning: false
#   message: false
# from: markdown+emoji
# comments: false
# ---

# %% [markdown]
# # Direction
#
# - Please submit your Jupyter Notebook for the Take-home Exam to the Brightspace with the name below:
#
#   - `danl-m1-exam-LASTNAME-FIRSTNAME.ipynb`\
#   ( e.g., `danl-m1-exam-choe-byeonghak.ipynb` )
#
# - The due is March 26, 2024, 7:00 P.M.
#
# - Please send Byeong-Hak an email (`bchoe@geneseo.edu`) if you have any questions.
#
# -   Please prepare a Jupyter/Python Notebook (`*.ipynb`) to address all questions.
#
# -   Make at least some simple comment (`# ...`) in each question.
#
# -   Make one text cell to explain things in each question.
#
# -   Import Python libraries you need here.

# %%
import pandas as pd
from itables import init_notebook_mode
from itables import show

from google.colab import data_table
data_table.enable_dataframe_formatter()

# %% [markdown]
# <br><br><br>
#
#
#
# # Part 1 - Beer Markets
#
# <br>
#
# <p align="center">
#   <img src="https://bcdanl.github.io/lec_figs/beer.png" width="600px">
# </p>
#
# <br>
#
#
# Load DataFrame for Part 1:

# %%
beer_mkts = pd.read_csv('https://bcdanl.github.io/data/beer_markets.csv')
show(beer_mkts)
# Out:
# <table id="itables_9bd6bf22_e0c9_4575_9de2_5f16bdd4604d" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>hh</th>
#       <th>_purchase_desc</th>
#       <th>quantity</th>
#       <th>brand</th>
#       <th>dollar_spent</th>
#       <th>beer_floz</th>
#       <th>price_per_floz</th>
#       <th>container</th>
#       <th>promo</th>
#       <th>market</th>
#       <th>buyertype</th>
#       <th>income</th>
#       <th>childrenUnder6</th>
#       <th>children6to17</th>
#       <th>age</th>
#       <th>employment</th>
#       <th>degree</th>
#       <th>cow</th>
#       <th>race</th>
#       <th>microwave</th>
#       <th>dishwasher</th>
#       <th>tvcable</th>
#       <th>singlefamilyhome</th>
#       <th>npeople</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_9bd6bf22_e0c9_4575_9de2_5f16bdd4604d:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[2000946, "BUD LT BR CN 12P", 1, "BUD LIGHT", 8.14, 144.0, 0.056528, "CAN", false, "RURAL ILLINOIS", "male", "20-60k", false, false, "50+", "none", "Grad", "none/retired/student", "white", true, true, "premium", false, "1"], [2003036, "BUD LT BR CN 24P", 1, "BUD LIGHT", 17.48, 288.0, 0.060694, "CAN", false, "ATLANTA", "married", "100-200k", false, false, "50+", "full", "College", "clerical/sales/service", "white", true, true, "basic", true, "2"], [2003036, "BUD LT BR CN 24P", 2, "BUD LIGHT", 33.92, 576.0, 0.058889, "CAN", false, "ATLANTA", "married", "100-200k", false, false, "50+", "full", "College", "clerical/sales/service", "white", true, true, "basic", true, "2"], [2003036, "BUD LT BR CN 30P", 2, "BUD LIGHT", 34.74, 720.0, 0.04825, "CAN", false, "ATLANTA", "married", "100-200k", false, false, "50+", "full", "College", "clerical/sales/service", "white", true, true, "basic", true, "2"], [2003036, "BUD LT BR CN 36P", 2, "BUD LIGHT", 40.48, 864.0, 0.046852, "CAN", false, "ATLANTA", "married", "100-200k", false, false, "50+", "full", "College", "clerical/sales/service", "white", true, true, "basic", true, "2"], [2003036, "BUD LT BR CN 36P", 2, "BUD LIGHT", 42.96, 864.0, 0.049722, "CAN", false, "ATLANTA", "married", "100-200k", false, false, "50+", "full", "College", "clerical/sales/service", "white", true, true, "basic", true, "2"], [2003036, "BUD LT BR CN 36P", 2, "BUD LIGHT", 40.96, 864.0, 0.047407, "CAN", false, "ATLANTA", "married", "100-200k", false, false, "50+", "full", "College", "clerical/sales/service", "white", true, true, "basic", true, "2"], [2001521, "BUD LT BR CN 6P", 5, "BUD LIGHT", 30.6, 480.0, 0.06375, "CAN", false, "RURAL INDIANA", "male", "60-100k", false, false, "50+", "none", "College", "none/retired/student", "white", true, true, "none", false, "1"], [2001521, "BUD LT BR CN 6P", 1, "BUD LIGHT", 9.99, 96.0, 0.104063, "CAN", false, "RURAL INDIANA", "male", "60-100k", false, false, "50+", "none", "College", "none/retired/student", "white", true, true, "none", false, "1"], [2001521, "BUD LT BR CN 6P", 5, "BUD LIGHT", 30.7, 480.0, 0.063958, "CAN", false, "RURAL INDIANA", "male", "60-100k", false, false, "50+", "none", "College", "none/retired/student", "white", true, true, "none", false, "1"], [2001521, "BUD LT BR CN 6P", 3, "BUD LIGHT", 18.36, 288.0, 0.06375, "CAN", false, "RURAL INDIANA", "male", "60-100k", false, false, "50+", "none", "College", "none/retired/student", "white", true, true, "none", false, "1"], [2001521, "BUD LT BR CN 6P", 5, "BUD LIGHT", 31.05, 480.0, 0.064687, "CAN", false, "RURAL INDIANA", "male", "60-100k", false, false, "50+", "none", "College", "none/retired/student", "white", true, true, "none", false, "1"], [2001521, "BUD LT BR CN 6P", 1, "BUD LIGHT", 9.99, 96.0, 0.104063, "CAN", false, "RURAL INDIANA", "male", "60-100k", false, false, "50+", "none", "College", "none/retired/student", "white", true, true, "none", false, "1"], [2001978, "BUD LT BR CN", 2, "BUD LIGHT", 2.98, 48.0, 0.062083, "CAN", false, "SYRACUSE", "married", "60-100k", false, false, "50+", "part", "HS", "clerical/sales/service", "white", true, true, "none", true, "2"], [2001978, "BUD LT BR CN", 1, "BUD LIGHT", 1.49, 24.0, 0.062083, "CAN", false, "SYRACUSE", "married", "60-100k", false, false, "50+", "part", "HS", "clerical/sales/service", "white", true, true, "none", true, "2"], [2007716, "BUD LT BR NRB LN 6P", 1, "BUD LIGHT", 3.0, 42.0, 0.071429, "NON REFILLABLE BOTTLE", false, "SURBURBAN NY", "married", "20-60k", false, false, "50+", "none", "HS", "none/retired/student", "white", true, true, "premium", false, "2"], [2007716, "BUD LT BR NRB LN 6P", 1, "BUD LIGHT", 4.99, 72.0, 0.069306, "NON REFILLABLE BOTTLE", false, "SURBURBAN NY", "married", "20-60k", false, false, "50+", "none", "HS", "none/retired/student", "white", true, true, "premium", false, "2"], [2008311, "BUD LT BR NRB LN 12P", 1, "BUD LIGHT", 9.99, 144.0, 0.069375, "NON REFILLABLE BOTTLE", true, "ATLANTA", "married", "60-100k", fals ...

# %% [markdown]
# - Each observation in `beer_mkts` is a household-level transaction record for a purchase of beer.
#
# ## Variable Description
#
#
# <br>
#
# - `hh`: an identifier of the household;
# - `X_purchase_desc`: details on the purchased item;
# - `quantity`: the number of items purchased;
# - `brand`: Bud Light, Busch Light, Coors Light, Miller Lite, or Natural Light;
# - `dollar_spent`: total dollar value of purchase;
# - `beer_floz`: total volume of beer, in fluid ounces;
# - `price_per_floz`: price per fl.oz. (i.e., beer spent/beer floz);
# - `container`: the type of container;
# - `promo`: Whether the item was promoted (coupon or otherwise);
# - `market`: Scan-track market (or state if rural);
# - demographic data, including gender, marital status, household income, class of work, race, education, age, the size of household, and whether or not the household has a microwave or a dishwasher.
#
#
# <br>
#
# <br>
#
# ## Question 1
#
# - Find the top 5 beer markets in terms of the number of households that purchased beer.
# - Find the top 5 beer markets in terms of the amount of total beer consumption.
#
# *Answer*:

# %%
# the top 5 beer markets in terms of the number of households that purchased beer
q1a = (
    beer_mkts
    .drop_duplicates(subset = ['hh', 'market'])
    .groupby('market')
    .size()
    .reset_index(name = 'n')
    .nlargest(5, 'n', keep = 'all')
)

show(q1a)
# Out:
# <table id="itables_66e39525_dcc2_4167_847c_2fc1d9de54bc" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market</th>
#       <th>n</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_66e39525_dcc2_4167_847c_2fc1d9de54bc:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[89, "TAMPA", 345], [7, "CHICAGO", 317], [35, "PHOENIX", 310], [86, "ST. LOUIS", 301], [18, "HOUSTON", 269]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_dom": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
q1b = (
    beer_mkts
    .groupby('market')[['beer_floz']]
    .sum()
    .nlargest(5, 'beer_floz', keep = "all")
)

show(q1b)
# Out:
# <table id="itables_a1894147_56e7_41b0_ba5b_6f7ca12aff96" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>beer_floz</th>
#     </tr>
#     <tr>
#       <th>market</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_a1894147_56e7_41b0_ba5b_6f7ca12aff96:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["TAMPA", 890418.0], ["PHOENIX", 675318.0], ["MIAMI", 632684.0], ["SAN ANTONIO", 631852.0], ["CHICAGO", 558878.0]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_dom": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# <br>
#
# ## Question 2
# - For households that purchased *BUD LIGHT* at least once, what fraction of households did purchase only *BUD LIGHT*?
#
# - For households that purchased *BUSCH LIGHT* at least once, what fraction of households did purchase only *BUSCH LIGHT*?
#
# - For households that purchased *COORS LIGHT* at least once, what fraction of households did purchase only *COORS LIGHT*?
#
# - For households that purchased *MILLER LITE* at least once, what fraction of households did purchase only *MILLER LITE*?
#
# - For households that purchased *NATURAL LIGHT* at least once, what fraction of households did purchase only *NATURAL LIGHT*?
#
# - Which beer brand does have the largest proportion of such loyal consumers?
#
#
# *Answer*:

# %% [markdown]
# Below calculates the number of households that have purchased BUD LIGHT at least once:

# %%
hh_bud = (
    beer_mkts
    .query('brand == "BUD LIGHT"')['hh']
    .unique()
)

# number of households that have purchased BUD LIGHT at least once
len(hh_bud)
# Out:
# 4657

# %% [markdown]
# Below calculates the number of households that have purchased only BUD LIGHT:

# %%
n_hh_loyal_bud = (
    beer_mkts[ beer_mkts['hh'].isin(hh_bud) ][['hh','brand']]
    .value_counts()
    .reset_index(name = 'n_purchases')
    .groupby('hh')
    .size()
    .reset_index(name = 'n_brands')
    .query('n_brands == 1')
)

# number of households that only bought `BUD`
len(n_hh_loyal_bud)
# Out:
# 3074

# %% [markdown]
# Therefore, among households that have purchased BUD LIGHT at least once, the proportion only bought BUD is:

# %%
len(n_hh_loyal_bud) / len(hh_bud)
# Out:
# 0.6600815975950183

# %% [markdown]
# Since we should repeat this over brands, let’s define a custom function and use for-loop:

# %%
def loyal_consumer_pct(df, item):
  hh_item = (
    df[ df['brand'] == item ]['hh']
    .unique()
    )

  n_hh_tot = len(hh_item)

  n_hh_loyal_item = (
    df[ df['hh'].isin(hh_item) ][['hh','brand']]
    .value_counts()
    .reset_index(name = 'n_purchases')
    .groupby('hh')
    .size()
    .reset_index(name = 'n')
    .query('n == 1')
    )

  n_hh_loyal = len(n_hh_loyal_item)

  return 100 * n_hh_loyal / n_hh_tot

for i in beer_mkts['brand'].unique():
  print(i, loyal_consumer_pct(beer_mkts, i))
# Out:
# BUD LIGHT 66.00815975950182
# BUSCH LIGHT 47.2972972972973
# COORS LIGHT 63.9080459770115
# MILLER LITE 63.129890453834115
# NATURAL LIGHT 50.96234309623431

# %% [markdown]
# Therefore, BUD LIGHT’s consumers tend to be most loyal.
#
# Note that more than 50% of households stick to only one beer brand they prefer!

# %% [markdown]
# <br><br><br>
#
#
#
#
# # Part 2 - Search Engine Marketing
#
#
# <br>
#
# <p align="center">
#   <img src="https://bcdanl.github.io/lec_figs/ebay-google-mkt.png" width="800px">
# </p>
#
# <br>
#
#
# Load DataFrame for Part 2:

# %%
paidsearch = pd.read_csv('https://bcdanl.github.io/data/paidsearch.csv')
show(paidsearch)
# Out:
# <table id="itables_44ff7864_8ac0_4bda_a848_1639c8989dbb" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>date</th>
#       <th>dma</th>
#       <th>treatment_period</th>
#       <th>search_stays_on</th>
#       <th>revenue</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_44ff7864_8ac0_4bda_a848_1639c8989dbb:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["1-Apr-12", 500, 0, 0, 76718.736], ["1-Apr-12", 501, 0, 1, 2096176.536], ["1-Apr-12", 502, 0, 1, 34993.8504], ["1-Apr-12", 503, 0, 1, 34198.7544], ["1-Apr-12", 504, 0, 1, 641014.2144], ["1-Apr-12", 505, 0, 0, 327989.3112], ["1-Apr-12", 506, 0, 1, 542373.984], ["1-Apr-12", 507, 0, 1, 49080.1968], ["1-Apr-12", 508, 0, 1, 230705.2944], ["1-Apr-12", 509, 0, 1, 51699.4488], ["1-Apr-12", 510, 0, 1, 287997.4008], ["1-Apr-12", 511, 0, 0, 564910.3944], ["1-Apr-12", 512, 0, 1, 241449.7464], ["1-Apr-12", 513, 0, 0, 82045.5336], ["1-Apr-12", 514, 0, 1, 157861.0944], ["1-Apr-12", 515, 0, 1, 149136.624], ["1-Apr-12", 516, 0, 1, 31408.4808], ["1-Apr-12", 517, 0, 0, 183142.6344], ["1-Apr-12", 518, 0, 1, 104594.7384], ["1-Apr-12", 519, 0, 1, 46660.8816], ["1-Apr-12", 520, 0, 1, 35264.8728], ["1-Apr-12", 521, 0, 0, 127206.432], ["1-Apr-12", 522, 0, 1, 35494.884], ["1-Apr-12", 523, 0, 1, 88089.7392], ["1-Apr-12", 524, 0, 1, 383967.6192], ["1-Apr-12", 525, 0, 0, 15370.7976], ["1-Apr-12", 526, 0, 1, 23615.9424], ["1-Apr-12", 527, 0, 1, 169157.592], ["1-Apr-12", 528, 0, 0, 626294.2176], ["1-Apr-12", 529, 0, 1, 112196.4552], ["1-Apr-12", 530, 0, 1, 34400.0232], ["1-Apr-12", 531, 0, 1, 51986.4984], ["1-Apr-12", 532, 0, 1, 115934.94], ["1-Apr-12", 533, 0, 1, 239605.0056], ["1-Apr-12", 534, 0, 0, 306014.9904], ["1-Apr-12", 535, 0, 1, 148151.592], ["1-Apr-12", 536, 0, 0, 48022.956], ["1-Apr-12", 537, 0, 1, 26071.8336], ["1-Apr-12", 538, 0, 1, 90076.1544], ["1-Apr-12", 539, 0, 1, 368264.844], ["1-Apr-12", 540, 0, 1, 45119.0592], ["1-Apr-12", 541, 0, 1, 82127.7144], ["1
72], ["1-Apr-12", 623, 0, 1, 466087.1544], ["1-Apr-12", 624, 0, 0, 23057.9568], ["1-Apr-12", 625, 0, 1, 58573.3896], ["1-Apr-12", 626, 0, 1, 5183.928], ["1-Apr-12", 627, 0, 0, 25270.4952], ["1-Apr-12", 628, 0, 1, 56192.1408], ["1-Apr-12", 630, 0, 1, 114492.8664], ["1-Apr-12" ...

# %% [markdown]
# ##  Variable Description
#
# - `dma`: an identification number of a designated market (DM) area `i`, defined by Nielsen (e.g., Boston, Los Angeles. [This webpage](https://www.spstechnical.com/DMACodes.htm) provides the list of DMA names.)
# - `treatment_period`: 0 if date is before May 22, 2012 and 1 after.
# - `search_stays_on`: 1 if the paid-search goes off in dma `i`, 0 otherwise.
# - `revenue`: eBay's sales revenue for dma `i` and date `t`
#
# <br>
#
# ## Question 3
#
# Summarize the mean value of `revenue` for each group of `search_stays_on` and for each `date`.
#
# *Answer*:

# %%
q3 = (
    paidsearch
    .groupby(['date', 'search_stays_on'])
    .agg(revenue_mean = ('revenue', 'mean'))
    .reset_index()
)

show(q3)
# Out:
# <table id="itables_638c034f_cc37_4ef5_befd_05029c38433b" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>date</th>
#       <th>search_stays_on</th>
#       <th>revenue_mean</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_638c034f_cc37_4ef5_befd_05029c38433b:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["1-Apr-12", 0, 93650.675824], ["1-Apr-12", 1, 120277.567977], ["1-Jul-12", 0, 84992.376494], ["1-Jul-12", 1, 110084.439448], ["1-Jun-12", 0, 106093.754576], ["1-Jun-12", 1, 133987.564344], ["1-May-12", 0, 123296.499318], ["1-May-12", 1, 154773.185324], ["10-Apr-12", 0, 119411.564929], ["10-Apr-12", 1, 146624.606011], ["10-Jul-12", 0, 112087.594059], ["10-Jul-12", 1, 142073.405087], ["10-Jun-12", 0, 89570.833094], ["10-Jun-12", 1, 113891.777493], ["10-May-12", 0, 104359.815212], ["10-May-12", 1, 133774.771183], ["11-Apr-12", 0, 115253.797659], ["11-Apr-12", 1, 143375.897713], ["11-Jul-12", 0, 106986.359118], ["11-Jul-12", 1, 135412.144276], ["11-Jun-12", 0, 113395.869529], ["11-Jun-12", 1, 145285.851448], ["11-May-12", 0, 97389.065224], ["11-May-12", 1, 122250.341155], ["12-Apr-12", 0, 110655.421306], ["12-Apr-12", 1, 137001.535656], ["12-Jul-12", 0, 103413.615776], ["12-Jul-12", 1, 134652.966085], ["12-Jun-12", 0, 110429.700353], ["12-Jun-12", 1, 142940.188749], ["12-May-12", 0, 80469.496588], ["12-May-12", 1, 100879.101583], ["13-Apr-12", 0, 105758.131553], ["13-Apr-12", 1, 132306.876659], ["13-Jul-12", 0, 103112.516329], ["13-Jul-12", 1, 129570.448868], ["13-Jun-12", 0, 105945.946941], ["13-Jun-12", 1, 137128.408428], ["13-May-12", 0, 86772.705459], ["13-May-12", 1, 109574.990315], ["14-Apr-12", 0, 87464.420153], ["14-Apr-12", 1, 110178.654592], ["14-Jul-12", 0, 84425.547706], ["14-Jul-12",
# %% [markdown]
# <br>
#
# ## Question 4
#
# Calculate the log difference between mean revenues in each group of `search_stays_on`. (This is the log of the average revenue in group of `search_stays_on` == 1 minus the log of the average revenue in group of `search_stays_on` == 0.)
#
# - For example, consider the following two observations:

# %%
# date        the daily mean vale of `revenue`   search_stays_on
# 1-Apr-12    93650.68                           0
# 1-Apr-12    120277.57                          1

# %% [markdown]
# - The log difference of daily mean revenues between the two group of `search_stays_on` for date 1-Apr-12 is log(120277.57) - log(93650.68).
#
# - *Hint*: Below example shows how we can calculate the log of `Value` using `np.log()`:

# %%
import pandas as pd
import numpy as np

# Creating a DataFrame
data = {'Value': [1, 10, 100, 1000, 10000]}
df = pd.DataFrame(data)

# Calculating logarithms
df['Log_natural'] = np.log(df['Value'])

# %% [markdown]
# *Answer*:

# %%
import numpy as np
q4 = (
    q3
    .pivot(
        index = 'date',
        columns = 'search_stays_on',
        values = 'revenue_mean'
    )
    .rename(columns = {0:'revenue_search_on',
                       1:'revenue_search_off'})
    .assign(
        log_revenue_search_on =
            lambda df: np.log(df['revenue_search_on']) - np.log(df['revenue_search_off'])
    )
)

show(q4)
# Out:
# <table id="itables_a12e3888_e335_4b93_a399_d3113b6845e8" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th>search_stays_on</th>
#       <th>revenue_search_on</th>
#       <th>revenue_search_off</th>
#       <th>log_revenue_search_on</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_a12e3888_e335_4b93_a399_d3113b6845e8:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["1-Apr-12", 93650.675824, 120277.567977, -0.25023], ["1-Jul-12", 84992.376494, 110084.439448, -0.258686], ["1-Jun-12", 106093.754576, 133987.564344, -0.233424], ["1-May-12", 123296.499318, 154773.185324, -0.227369], ["10-Apr-12", 119411.564929, 146624.606011, -0.2053], ["10-Jul-12", 112087.594059, 142073.405087, -0.237063], ["10-Jun-12", 89570.833094, 113891.777493, -0.240219], ["10-May-12", 104359.815212, 133774.771183, -0.248313], ["11-Apr-12", 115253.797659, 143375.897713, -0.218333], ["11-Jul-12", 106986.359118, 135412.144276, -0.235622], ["11-Jun-12", 113395.869529, 145285.851448, -0.247818], ["11-May-12", 97389.065224, 122250.341155, -0.227357], ["12-Apr-12", 110655.421306, 137001.535656, -0.213571], ["12-Jul-12", 103413.615776, 134652.966085, -0.263964], ["12-Jun-12", 110429.700353, 142940.188749, -0.258047], ["12-May-12", 80469.496588, 100879.101583, -0.226045], ["13-Apr-12", 105758.131553, 132306.876659, -0.223969], ["13-Jul-12", 103112.516329, 129570.448868, -0.228404], ["13-Jun-12", 105945.946941, 137128.408428, -0.257989], ["13-May-12", 86772.705459, 109574.990315, -0.233317], ["14-Apr-12", 87464.420153, 110178.654592, -0.230871], ["14-Jul-12", 84425.547706, 108829.567166, -0.253913], ["14-Jun-12", 104822.342471, 132038.433431, -0.230826], ["14-May-12", 115950.242435, 145974.192693, -0.230269], ["15-Apr-12", 97746.278506, 122472.929206, -0.225515], ["15-Jul-12", 92793.335
"2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 2.0, 769.0, 0, 0.601069], [1327, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 1.0, 735.0, 1, 0.626499], [1349, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 2.0, 691.0, 0, 0.61693], [1371, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 3.0, 647.0, 1, 0.616814], [1399, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 1.0, 610.0, 1, 0.660544], [1424, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 2.0, 576.0, 1, 0.646453], [1449, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 1.0, 535.0, 0, 0.686843], [1487, "2023_01_ARI_WAS", 8.0, 1, "ARI", 2, 1.0, 531.0, 0, 0.45712], [1516,  ...

# %% [markdown]
# - `NFL2023_stuffs` is the DataFrame that contains information about NFL games in year 2022, in which the unit of observation is a single play for each drive in a NFL game.
#
#
# ## Variable description
#
# - `play_id`: Numeric play identifier that when used with `game_id` and `drive` provides the unique identifier for a single play
# - `game_id`: Ten digit identifier for NFL game.
# - `drive`: Numeric drive number in the game.
# - `week`: Season week.
# - `posteam`: String abbreviation for the team with possession.
# - `qtr`: Quarter of the game (5 is overtime).
# - `half_seconds_remaining`: Numeric seconds remaining in the half.
# - `down`: The down for the given play.
#   - Basically you get four attempts (aka downs) to move the ball 10 yards (by either running with it or passing it).
#   - If you make 10 yards then you get another set of four downs.
# - `pass`: Binary indicator if the play was a pass play.
# - `wp`: Estimated winning probability for the `posteam` given the current situation at the start of the given play.
#
# <br>
#
# ## Question 5
# In DataFrame, `NFL2023_stuffs`, remove observations for which values of `posteam` is missing.
#
# *Answer*:

# %%
q5 = (
    NFL2023_stuffs
    .dropna(subset = ['posteam'])
)

q5['posteam'].notna().sum() == q5.shape[0]
# Out:
# True

# %% [markdown]
# <br>
#
#
# ## Question 6
# - Calculate the mean value of `pass` for each `posteam` when all the following conditions hold:
#   1. `wp` is greater than 20% and less than 75%;
#   2. `down` is less than or equal to 2; and
#   3. `half_seconds_remaining` is greater than 120.
#
# *Answer*:

# %%
q6 = (
    NFL2023_stuffs
    .query('wp > .2 & wp < .75 & down <= 2 & half_seconds_remaining > 120')
    .groupby('posteam')[['pass']]
    .agg(
        pass_mean = ('pass', 'mean')
    ).
    sort_values('pass_mean', ascending = False)
)

show(q6)
# Out:
# <table id="itables_1934c795_2abb_4039_a7ba_a0ded2d052d7" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pass_mean</th>
#     </tr>
#     <tr>
#       <th>posteam</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_1934c795_2abb_4039_a7ba_a0ded2d052d7:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["CIN", 0.624176], ["KC", 0.609294], ["WAS", 0.606335], ["BAL", 0.577002], ["DAL", 0.576355], ["LAC", 0.571956], ["PHI", 0.570265], ["LA", 0.550752], ["SEA", 0.545098], ["BUF", 0.544256], ["CLE", 0.539877], ["SF", 0.534553], ["MIA", 0.532995], ["MIN", 0.532544], ["JAX", 0.526932], ["NYG", 0.523077], ["IND", 0.521042], ["TB", 0.511719], ["GB", 0.509728], ["NE", 0.507592], ["DET", 0.504016], ["HOU", 0.501053], ["DEN", 0.5], ["NO", 0.498952], ["NYJ", 0.492958], ["LV", 0.491003], ["CHI", 0.476658], ["TEN", 0.465979], ["ATL", 0.462963], ["ARI", 0.461197], ["CAR", 0.460554], ["PIT", 0.447791]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "warn_on_dom": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# <br>
#
#
# ## Question 7
# - Consider the following DataFrame, `NFL2023_epa`:

# %%
NFL2023_epa = pd.read_csv('https://bcdanl.github.io/data/NFL2023_epa.csv')
show(NFL2023_epa)
# Out:
# <table id="itables_e74f17d7_5a49_469a_8514_ada123502609" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>play_id</th>
#       <th>game_id</th>
#       <th>drive</th>
#       <th>posteam</th>
#       <th>receiver</th>
#       <th>passer</th>
#       <th>epa</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e74f17d7_5a49_469a_8514_ada123502609:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[39, "2023_01_ARI_WAS", 1.0, "WAS", "NaN", "NaN", 0.0], [55, "2023_01_ARI_WAS", 1.0, "WAS", "NaN", "NaN", -0.336103], [77, "2023_01_ARI_WAS", 1.0, "WAS", "J.Dotson", "S.Howell", 0.703308], [102, "2023_01_ARI_WAS", 1.0, "WAS", "NaN", "NaN", 0.469799], [124, "2023_01_ARI_WAS", 1.0, "WAS", "L.Thomas", "S.Howell", -0.521544], [147, "2023_01_ARI_WAS", 1.0, "WAS", "J.Dotson", "S.Howell", 1.173155], [172, "2023_01_ARI_WAS", 1.0, "WAS", "C.Samuel", "S.Howell", -0.515452], [197, "2023_01_ARI_WAS", 1.0, "WAS", "L.Thomas", "S.Howell", -0.872005], [220, "2023_01_ARI_WAS", 1.0, "WAS", "C.Samuel", "S.Howell", -1.430719], [245, "2023_01_ARI_WAS", 1.0, "WAS", "NaN", "NaN", -0.41589], [276, "2023_01_ARI_WAS", 2.0, "ARI", "NaN", "NaN", -0.877485], [310, "2023_01_ARI_WAS", 2.0, "ARI", "NaN", "NaN", -0.069434], [332, "2023_01_ARI_WAS", 2.0, "ARI", "Z.Ertz", "J.Dobbs", 1.648779], [357, "2023_01_ARI_WAS", 2.0, "ARI", "Z.Pascal", "J.Dobbs", -0.579366], [380, "2023_01_ARI_WAS", 2.0, "ARI", "Z.Ertz", "J.Dobbs", -1.215581], [405, "2023_01_ARI_WAS", 2.0, "ARI", "NaN", "NaN", -0.585785], [427, "2023_01_ARI_WAS", 2.0, "ARI", "NaN", "NaN", 1.07553], [469, "2023_01_ARI_WAS", 3.0, "WAS", "NaN", "S.Howell", 0.767201], [526, "2023_01_ARI_WAS", 3.0, "WAS", "L.Thomas", "S.Howell", 0.484837], [558, "2023_01_ARI_WAS", 3.0, "WAS", "NaN", "NaN", 0.043073], [580, "2023_01_ARI_WAS", 3.0, "WAS", "J.Dotson", "S.Howell", 1.409476], [621, "2023_01_ARI_WAS", 3.0, "WAS", "NaN", "NaN", -0.778208], [643, "2023_01_ARI_WAS", 3.0, "WAS", "T.McLaurin", "S.Howell", 2.962082], [677, "2023_01_ARI_WAS", 3.0, "WAS", "NaN", "NaN", 0.188874], [699, "2023_01_ARI_WAS", 3.0, "WAS", "B.Robinson", "S.Howell", 1.590677], [725, "2023_01_ARI_WAS", 3.0, "WAS", "NaN", "NaN", 0.067573], [740, "2023_01_ARI_WAS", 4.0, "ARI", "NaN", "NaN", -0.0], [763, "2023_01_ARI_WAS", 4.0, "ARI", "NaN", "NaN", -0.042103], [790, "2023_01_ARI_WAS", 4.0, "ARI", "NaN", "NaN", 2.17307], [812, "2023_01_ARI_WAS", 4.0, "ARI", "J.Conner", "J.Dobbs", -0.925954], [842, "2023_01_ARI_WAS", 4.0, "ARI", "R.Moore", "J.Dobbs", 2.809702], [883, "2023_01_ARI_WAS", 4.0, "ARI", "Z.Ertz", "J.Dobbs", -0.472698], [913, "2023_01_ARI_WAS", 4.0, "ARI", "NaN", "NaN", -0.747438], [935, "2023_01_ARI_WAS", 4.0, "ARI", "Z.Ertz", "J.Dobbs", -0.795774], [958, "2023_01_ARI_WAS", 4.0, "ARI", "NaN", "NaN", 0.125728], [987, "2023_01_ARI_WAS", 5.0, "WAS", "NaN", "NaN", 0.0], [1010, "2023_01_ARI_WAS", 5.0, "WAS", "NaN", "S.Howell", -1.053971], [1045, "2023_01_ARI_WAS", 5.0, "WAS", "L.Thomas", "S.Howell", -0.87719], [1081, "2023_01_ARI_WAS", 5.0, "WAS", "NaN", "NaN", 0.0], [1106, "2023_01_ARI_WAS", 5.0, "WAS", "L.Thomas", "S.Howell", 2.12112], [1140, "2023_01_ARI_WAS", 5.0, "WAS", "J.Dotson", "S.Howell", -4.904358], [1167, "2023_01_ARI_WAS", 6.0, "ARI", "Z.Ertz", "J.Dobbs", -0.064859], [1192, "2023_01_ARI_WAS", 6.0, "ARI", "NaN", "NaN", -1.227382], [1214, "2023_01_ARI_WAS", 6.0, "ARI", "M.Brown", "J.Dobbs", -0.982245], [1237, "2023_01_ARI_WAS", 6.0, "ARI", "NaN", "NaN", 2.098748], [1257, "2023_01_ARI_WAS", 7.0, "WAS", "NaN", "NaN", 0.0], [1280, "2023_01_ARI_WAS", 7.0, "WAS", "NaN", "NaN", 0.225302], [1302, "2023_01_ARI_WAS", 7.0, "WAS", "NaN", "NaN", 0.508856], [1327, "2023_01_ARI_WAS", 7.0, "WAS", "NaN", "S.Howell", -0.04526], [1349, "2023_01_ARI_WAS", 7.0, "WAS", "NaN", "NaN", -0.175788], [1371, "2023_01_ARI_WAS", 7.0, "WAS", "T.McLaurin", "S.Howell", 1.642313], [1399, "2023_01_ARI_WAS", 7.0, "WAS", "C.Samuel", "S.Howell", -0.474221], [1424, "2023_01_ARI_WAS", 7.0, "WAS", "C.Turner", "S.Howell", 1.498291], [1449, "2023_01_ARI_WAS", 7.0, "WAS", "NaN", "NaN", -4.776598], [1487, "2023_01_ARI_WAS", 8.0, "ARI", "NaN", "NaN", -0.383475], [1516, "2023_01_ARI_WAS", 8.0, "ARI", "M.Brown", "J.Dobbs", -0.569984], [1552, "2023_01_ARI_WAS", 8.0, "ARI", "NaN", "NaN", 0.219966], [1581, "2023_01_ARI_WAS", 8.0, "ARI", "NaN", "J.Dobbs", -1.362236], [1601, "2023_01_ARI_WAS", 8.0, "ARI", "NaN", "NaN", -0.80714], [1620, "2023_01_ARI_WAS", 9.0, "WAS",  ...

# %% [markdown]
# ### Variable Description for `NFL2023_epa`
#
#   - `play_id`: Numeric play identifier that when used with `game_id` and `drive` provides the unique identifier for a single play
#   - `game_id`: Ten digit identifier for NFL game.
#   - `drive`: Numeric drive number in the game.
#   - `posteam`: String abbreviation for the team with possession.
#   - `passer`: Name of the player who passed a ball to a receiver by initially taking a three-step drop and backpedaling into the pocket to make a pass. (Mostly, they are quarterbacks)
#   - `receiver`: Name of the receiver.
#   - `epa`: Expected points added (EPA) by the `posteam` for the given play.
#
# <br>
#
# - Create the DataFrame, `NFL2023_stuffs_EPA`, that includes
#   1. All the variables in the DataFrame, `NFL2023_stuffs`;
#   2. The variables, `passer`, `receiver`, and `epa`, from the DataFrame, `NFL2023_epa`.
# by joining the two DataFrames.
#
# - In the resulting DataFrame, `NFL2023_stuffs_EPA`, remove observations with `NA` in `passer`.
#
# *Answer*:

# %%
NFL2023_stuffs_EPA = (
    NFL2023_stuffs
    .merge(NFL2023_epa, on = ['play_id', 'game_id', 'drive'], how = 'left')
    .dropna(subset = ['passer'])
)

show(NFL2023_stuffs_EPA)
# Out:
# <table id="itables_628cccc5_47be_4d01_af95_3ca993217283" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>play_id</th>
#       <th>game_id</th>
#       <th>drive</th>
#       <th>week</th>
#       <th>posteam_x</th>
#       <th>qtr</th>
#       <th>down</th>
#       <th>half_seconds_remaining</th>
#       <th>pass</th>
#       <th>wp</th>
#       <th>posteam_y</th>
#       <th>receiver</th>
#       <th>passer</th>
#       <th>epa</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.1/dt_bundle.js';
#
#     document.querySelectorAll("#itables_628cccc5_47be_4d01_af95_3ca993217283:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[3, 77, "2023_01_ARI_WAS", 1.0, 1, "WAS", 1, 2.0, 1770.0, 1, 0.539621, "WAS", "J.Dotson", "S.Howell", 0.703308], [5, 124, "2023_01_ARI_WAS", 1.0, 1, "WAS", 1, 1.0, 1696.0, 1, 0.572573, "WAS", "L.Thomas", "S.Howell", -0.521544], [6, 147, "2023_01_ARI_WAS", 1.0, 1, "WAS", 1, 2.0, 1692.0, 1, 0.554537, "WAS", "J.Dotson", "S.Howell", 1.173155], [7, 172, "2023_01_ARI_WAS", 1.0, 1, "WAS", 1, 1.0, 1654.0, 1, 0.584447, "WAS", "C.Samuel", "S.Howell", -0.515452], [8, 197, "2023_01_ARI_WAS", 1.0, 1, "WAS", 1, 2.0, 1616.0, 1, 0.566532, "WAS", "L.Thomas", "S.Howell", -0.872005], [9, 220, "2023_01_ARI_WAS", 1.0, 1, "WAS", 1, 3.0, 1611.0, 1, 0.530844, "WAS", "C.Samuel", "S.Howell", -1.430719], [13, 332, "2023_01_ARI_WAS", 2.0, 1, "ARI", 1, 3.0, 1491.0, 1, 0.459911, "ARI", "Z.Ertz", "J.Dobbs", 1.648779], [14, 357, "2023_01_ARI_WAS", 2.0, 1, "ARI", 1, 1.0, 1452.0, 1, 0.49582, "ARI", "Z.Pascal", "J.Dobbs", -0.579366], [15, 380, "2023_01_ARI_WAS", 2.0, 1, "ARI", 1, 2.0, 1448.0, 1, 0.480152, "ARI", "Z.Ertz", "J.Dobbs", -1.215581], [18, 469, "2023_01_ARI_WAS", 3.0, 1, "WAS", 1, 1.0, 1355.0, 1, 0.528502, "WAS", "NaN", "S.Howell", 0.767201], [19, 526, "2023_01_ARI_WAS", 3.0, 1, "WAS", 1, 1.0, 1331.0, 1, 0.546262, "WAS", "L.Thomas", "S.Howell", 0.484837], [21, 580, "2023_01_ARI_WAS", 3.0, 1, "WAS", 1, 3.0, 1270.0, 1, 0.554581, "WAS", "J.Dotson", "S.Howell", 1.409476], [23, 643, "2023_01_ARI_WAS", 3.0, 1, "WAS", 1, 2.0, 1208.0, 1, 0.561314, "WAS", "T.McLaurin", "S.Howell", 2.962082], [25, 699, "2023_01_ARI_WAS", 3.0, 1, "WAS", 1, 2.0, 1162.0, 1, 0.677953, "WAS", "B.Robinson", "S.Howell", 1.590677], [30, 812, "2023_01_ARI_WAS", 4.0, 1, "ARI", 1, 1.0, 1081.0, 1, 0.337, "ARI", "J.Conner", "J.Dobbs", -0.925954], [31, 842, "2023_01_ARI_WAS", 4.0, 1, "ARI", 1, 2.0, 1036.0, 1, 0.314306, "ARI", "R.Moore", "J.Dobbs", 2.809702], [33, 883, "2023_01_ARI_WAS", 4.0, 1, "ARI", 1, 1.0, 1003.0, 1, 0.382817, "ARI", "Z.Ertz", "J.Dobbs", -0.472698], [35, 935, "2023_01_ARI_WAS", 4.0, 1, "ARI", 1, 3.0, 960.0, 1, 0.34102, "ARI", "Z.Ertz", "J.Dobbs", -0.795774], [38, 1010, "2023_01_ARI_WAS", 5.0, 1, "WAS", 1, 1.0, 953.0, 1, 0.654758, "WAS", "NaN", "S.Howell", -1.053971], [39, 1045, "2023_01_ARI_WAS", 5.0, 1, "WAS", 1, 2.0, 917.0, 1, 0.627769, "WAS", "L.Thomas", "S.Howell", -0.87719], [41, 1106, "2023_01_ARI_WAS", 5.0, 1, "WAS", 2, 2.0, 900.0, 1, 0.616057, "WAS", "L.Thomas", "S.Howell", 2.12112], [42, 1140, "2023_01_ARI_WAS", 5.0, 1, "WAS", 2, 1.0, 894.0, 1, 0.658424, "WAS", "J.Dotson", "S.Howell", -4.904358], [43, 1167, "2023_01_ARI_WAS", 6.0, 1, "ARI", 2, 1.0, 886.0, 1, 0.466075, "ARI", "Z.Ertz", "J.Dobbs", -0.064859], [45, 1214, "2023_01_ARI_WAS", 6.0, 1, "ARI", 2, 3.0, 814.0, 1, 0.418897, "ARI", "M.Brown", "J.Dobbs", -0.982245], [50, 1327, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 1.0, 735.0, 1, 0.626499, "WAS", "NaN", "S.Howell", -0.04526], [52, 1371, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 3.0, 647.0, 1, 0.616814, "WAS", "T.McLaurin", "S.Howell", 1.642313], [53, 1399, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 1.0, 610.0, 1, 0.660544, "WAS", "C.Samuel", "S.Howell", -0.474221], [54, 1424, "2023_01_ARI_WAS", 7.0, 1, "WAS", 2, 2.0, 576.0, 1, 0.646453, "WAS", "C.Turner", "S.Howell", 1.498291], [57, 1516, "2023_01_ARI_WAS", 8.0, 1, "ARI", 2, 2.0, 494.0, 1, 0.453499, "ARI", "M.Brown", "J.Dobbs", -0.569984], [59, 1581, "2023_01_ARI_WAS", 8.0, 1, "ARI", 2, 3.0, 422.0, 1, 0.431449, "ARI", "NaN", "J.Dobbs", -1.362236], [61, 1620, "2023_01_ARI_WAS", 9.0, 1, "WAS", 2, 1.0, 377.0, 1, 0.650322, "WAS", "T.McLaurin", "S.Howell", 0.719232], [62, 1657, "2023_01_ARI_WAS", 9.0, 1, "WAS", 2, 1.0, 349.0, 1, 0.660544, "WAS", "NaN", "S.Howell", -0.398985], [63, 1679, "2023_01_ARI_WAS", 9.0, 1, "WAS", 2, 2.0, 311.0, 1, 0.646453, "WAS", "T.McLaurin", "S.Howell", -0.667901], [64, 1702, "2023_01_ARI_WAS", 9.0, 1, "WAS", 2, 3.0, 306.0, 1, 0.615544, "WAS", "NaN", "S.Howell", -2.190107], [67, 1764, "2023_01_ARI_WAS", 10.0, 1, "ARI", 2, 2.0, 227.0, 1, 0.459277, "ARI", "T.McBride", "J.Dobbs", 0. ...

# %% [markdown]
# <br>
